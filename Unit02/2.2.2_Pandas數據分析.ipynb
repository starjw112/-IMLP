# %% [markdown]
# # Pandas數據分析
#
# 今天介紹資料分析近來很紅的 pandas 套件, 作者是 Wes McKinney。Python 會成為一個數據分析的熱門語言, 和 pandas 的出現也有相當的關係。
#
# 但是 pandas 雖然功能強, 但有些地方沒那麼直覺, 有時會讓大家以為是個深奧的套件。其實你大約可以把 pandas 想成「Python 的 Excel」, 但是功能更強、更有彈性、也有更多的可能性。
#
# 下面介紹個基本上就是把 pandas 當 Excel 學的影片, 相信大家會覺得很親切。<br>
# https://youtu.be/9d5-Ti6onew

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1 開始使用 `pandas`
#
# 首先我們來讀入一個 CSV 檔, 這裡有個「假的」學測成績, 叫 `grades.csv` 我們來練習一下。

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv("/content/drive/MyDrive/IMLP375/Unit02/data/grades.csv")
# Out:
# Mounted at /content/drive

# %% [markdown]
# 用 `df` 是標準的叫法 (雖然這名稱我們隨便取也可以), 意思是 Data Frame, 這是 `pandas` 兩大資料結構之一。我們可以把 Data Frame 想成一張表格 (雖然其實可以是很多張表格)。
#
# 我們來看看我們 `df` 的前五筆資料。

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %% [markdown]
# 如果你曾經手動讀入 CSV 檔, 就知道這省了多少事 (雖然我個人還挺喜歡純手動帶進 CSV)。

# %% [markdown]
# #### Excel 檔也可以快速讀入
#
# 不只 CSV 檔, 很多資料檔案, 像 Excel 檔都很容易在 `pandas` 完成。使用法是這樣:
#
#     df2 = pd.read_excel('filename.xls', 'sheetname')
#
# 其中 sheetname 那裡要放工作表的名稱, 如果是中文的最好改成英文。

# %% [markdown]
# ## 2 Pandas 基本資料結構
#
# Pandas 有兩個基本資料結構:
#
# * <b style="color:red;">DataFrame</b>: 可以想成一個表格。
# * <b style="color:red;">Series</b>: 表格的某一列、某一行, 基本上就是我們以前的 list 或 array
#
# 一個 DataFrame, 我們有 `index` (列的名稱), `columns` (行的名稱)。
#
# #### DataFrame
#
# ![DataFrame 的結構](images/indexcol.png)

# %% [markdown]
# #### Series
#
# 剛剛說 series 大概就是一個 list, 一個 array。其實更精準的說, 其實是一個有 "index" 的 array。
#
# DataFrame 的每一行或每一列其實也都是一個 series。我們來看個例子, 例如所有同學的國文成績, 就是一個 series。

# %%
df['國文']
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# 在 Python 3 中, 我們終於可以和英文同步, 用這種很炫的方式叫出所有國文成績。

# %%
df.國文
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# #### 資料畫出來
#
# 要畫個圖很容易。

# %%
df.國文.plot()

# %% [markdown]
# 當然, 在這個例子中, 其實畫 histogram 圖更有意義一點。

# %%
df.國文.hist(bins = 15)

# %% [markdown]
# ## 3 一些基本的資料分析

# %% [markdown]
# 算平均。

# %%
df.國文.mean()
# Out:
# 11.39

# %% [markdown]
# 算標準差。

# %%
df.國文.std()
# Out:
# 2.196852661459484

# %% [markdown]
# 不如就該算的都幫我們算算...

# %%
df.describe()
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %% [markdown]
# 有時我們很愛看的相關係數矩陣。

# %%
df.corr()
# Out:
#           國文        英文        數學        自然        社會
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000

# %% [markdown]
# 只算兩科間的相關係數當然也可以。

# %%
df.國文.corr(df.數學)
# Out:
# -0.3108989822179331

# %% [markdown]
# ## 4 增加一行

# %% [markdown]
# ### 【技巧】
#
# 我們增加一行, 加入總級分。

# %%
df["總級分"] = df.sum(axis = 1)
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分
# 0  劉俊安   9  10  15  10  13   57
# 1  胡玉華  10  10  10   8   9   47
# 2  黃淑婷  13  15   8  11  14   61
# 3  陳上紫  10  10   8   9  14   51
# 4  崔靜成  13  12  14  12  13   64

# %% [markdown]
# ### 【技巧】
#
# 有計算的當然也可以的。

# %%
df["加權"] = df.國文 + df.英文 + df.數學 * 2
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  加權
# 0  劉俊安   9  10  15  10  13   57  49
# 1  胡玉華  10  10  10   8   9   47  40
# 2  黃淑婷  13  15   8  11  14   61  44
# 3  陳上紫  10  10   8   9  14   51  36
# 4  崔靜成  13  12  14  12  13   64  53

# %% [markdown]
# ## 5 排序和 index 重設

# %% [markdown]
# ### 【重點】排序的方法
#
# 我們依總級分來排序。

# %%
df.sort_values(by = '總級分', ascending = False).head(10)
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分  加權
# 80  施雅鈴  13  15  12  13  13   66  52
# 12  李正偉  11  15  11  14  15   66  48
# 54  陳怡潔  15  15   9  15  11   65  48
# 25  蔡亦瑄  13  13  14  13  12   65  54
# 57  胡淳茜  12  15  14  13  11   65  55
# 37  曾怡君  11  12  15  13  14   65  53
# 48  陳怡婷  15  14  12   9  15   65  53
# 64  俞志峰   9  14  13  14  15   65  49
# 83  李士賢  10  14  15  13  13   65  54
# 87  趙偉希  10  13  14  13  15   65  51

# %% [markdown]
# ### 【重點】排序的方法
#
# 加權分最高, 同分才看總級分

# %%
df2 = df.sort_values(by = ["加權", "總級分"], ascending = False)

# %% [markdown]
# ### 【重點】重設 index

# %%
df2.index = range(1, 101)
df2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  加權
# 1  吳志遠  13  15  15   8   8   59  58
# 2  胡淳茜  12  15  14  13  11   65  55
# 3  詹威德  12  13  15  10  14   64  55
# 4  蔡亦瑄  13  13  14  13  12   65  54
# 5  李士賢  10  14  15  13  13   65  54

# %% [markdown]
# ## 6 篩出我們要的資料
#
# 基本上和 NumPy 的 array 篩法很像。

# %% [markdown]
# ### 【重點】
#
# 找出數學滿級分同學。

# %%
df2[df2.數學 == 15]
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分  加權
# 1   吳志遠  13  15  15   8   8   59  58
# 3   詹威德  12  13  15  10  14   64  55
# 5   李士賢  10  14  15  13  13   65  54
# 7   曾怡君  11  12  15  13  14   65  53
# 10  林哲法  14   9  15  10  14   62  53
# 13  陳竹伯  10  12  15  10  14   61  52
# 15  葉儀依   9  13  15   8  14   59  52
# 18  周育霖   9  12  15  13  12   61  51
# 21  張雅彬  10  11  15  12   8   56  51
# 22  芮秋辛  11  10  15  10   8   54  51
# 25  胡勝傑   8  11  15  10  15   59  49
# 26  劉俊安   9  10  15  10  13   57  49
# 42  段冠廷   9   8  15  12  15   59  47

# %% [markdown]
# ### 【重點】
#
# 找出數學和英文都滿級分的同學。要注意 `and` 要用 `&`, `or` 要用 `|`。每個條件一定要加弧號。

# %%
df2[(df2.數學 == 15) & (df2.英文 == 15)]
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  加權
# 1  吳志遠  13  15  15   8   8   59  58

# %% [markdown]
# ## 7 刪除一行或一列

# %% [markdown]
# ### 【重點】刪掉一行
#
# 我們來刪掉總級分的那行。

# %%
df2.drop("總級分", axis = 1)
df2
# Out:
#       姓名  國文  英文  數學  自然  社會  總級分  加權
# 1    吳志遠  13  15  15   8   8   59  58
# 2    胡淳茜  12  15  14  13  11   65  55
# 3    詹威德  12  13  15  10  14   64  55
# 4    蔡亦瑄  13  13  14  13  12   65  54
# 5    李士賢  10  14  15  13  13   65  54
# ..   ...  ..  ..  ..  ..  ..  ...  ..
# 96   陳上紫  10  10   8   9  14   51  36
# 97   胡凱琳  10   8   9   9  15   51  36
# 98   林建亨   9  11   8   8  11   47  36
# 99   梁慧君   9   8   8   8  12   45  33
# 100  吳文伯   8   8   8  15  12   51  32
#
# [100 rows x 8 columns]

# %% [markdown]
# ### 【重點】改變原有的 DataFrame
#
# 我們會發現 `pandas` 很多動作都沒有更改原有的 DataFrame, 真的要改要加入
#
#     inplace=True

# %%
df2.drop("總級分", axis = 1, inplace = True)
df2
# Out:
#       姓名  國文  英文  數學  自然  社會  加權
# 1    吳志遠  13  15  15   8   8  58
# 2    胡淳茜  12  15  14  13  11  55
# 3    詹威德  12  13  15  10  14  55
# 4    蔡亦瑄  13  13  14  13  12  54
# 5    李士賢  10  14  15  13  13  54
# ..   ...  ..  ..  ..  ..  ..  ..
# 96   陳上紫  10  10   8   9  14  36
# 97   胡凱琳  10   8   9   9  15  36
# 98   林建亨   9  11   8   8  11  36
# 99   梁慧君   9   8   8   8  12  33
# 100  吳文伯   8   8   8  15  12  32
#
# [100 rows x 7 columns]

# %% [markdown]
# ### 【重點】刪掉一列
#
# 刪掉列就是指定要刪去的 index。

# %%
df2.drop(5).head()
# Out:
#     姓名  國文  英文  數學  自然  社會  加權
# 1  吳志遠  13  15  15   8   8  58
# 2  胡淳茜  12  15  14  13  11  55
# 3  詹威德  12  13  15  10  14  55
# 4  蔡亦瑄  13  13  14  13  12  54
# 6  童心怡  13  13  14   8  13  54

# %%
df2[df2.姓名 == "李士賢"]
# Out:
#     姓名  國文  英文  數學  自然  社會  加權
# 5  李士賢  10  14  15  13  13  54

# %% [markdown]
# ### 【重點】刪掉一列
#
# 通常刪掉符合條件的比較合理 (注意是找到要刪掉的部份, 再找出相對的 index)。

# %%
df2.drop(df2[df2.姓名 == "李士賢"].index).head()
# Out:
#     姓名  國文  英文  數學  自然  社會  加權
# 1  吳志遠  13  15  15   8   8  58
# 2  胡淳茜  12  15  14  13  11  55
# 3  詹威德  12  13  15  10  14  55
# 4  蔡亦瑄  13  13  14  13  12  54
# 6  童心怡  13  13  14   8  13  54

# %% [markdown]
# ## 8 真實股價資料
#
# 有個從 `Pandas` 獨立出來的套件叫 `pandas-datareader`, 幾經波折, 先是 Yahoo! 的財務資料不能用, 後來又是 Google 的資料不能用, 不過至少現在看來 Yahoo! 還可以使用。
#
# 安裝 `pandas-datareader` 就標準 `conda` 安裝:
#
#     conda install pandas-datareader
#
# 如果裝過, 但很久沒更新就用:
#
#     conda update pandas-datareader

# %% [markdown]
# ### 【例子】 分析 Apple 股價

# %%
import pandas_datareader as pdr
df = pdr.get_data_yahoo('AAPL')

# %%
# 為防止網路有問題, 我們把這個檔案以 aapl.csv 存起來, 可以這樣讀入。
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('/content/drive/MyDrive/IMLP375/Unit02/data/aapl.csv', index_col="Date")

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2009-12-31  30.447144  30.478571  30.080000  30.104286  26.986492   88102700
# 2010-01-04  30.490000  30.642857  30.340000  30.572857  27.406532  123432400
# 2010-01-05  30.657143  30.798571  30.464285  30.625713  27.453915  150476200
# 2010-01-06  30.625713  30.747143  30.107143  30.138571  27.017223  138040000
# 2010-01-07  30.250000  30.285715  29.864286  30.082857  26.967278  119282800

# %% [markdown]
# #### 只要最後 300 個交易日!

# %%
df = df[-300:]
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-10-03  112.709999  113.050003  112.279999  112.519997  110.173546
# 2016-10-04  113.059998  114.309998  112.629997  113.000000  110.643539
# 2016-10-05  113.400002  113.660004  112.690002  113.050003  110.692505
# 2016-10-06  113.699997  114.339996  113.129997  113.889999  111.514984
# 2016-10-07  114.309998  114.559998  113.510002  114.059998  111.681435
# ...                ...         ...         ...         ...         ...
# 2017-12-04  172.479996  172.619995  169.630005  169.800003  169.800003
# 2017-12-05  169.059998  171.520004  168.399994  169.639999  169.639999
# 2017-12-06  167.500000  170.199997  166.460007  169.009995  169.009995
# 2017-12-07  169.029999  170.440002  168.910004  169.320007  169.320007
# 2017-12-08  170.490005  171.000000  168.820007  169.369995  169.369995
#
#               Volume
# Date
# 2016-10-03  21701800
# 2016-10-04  29736800
# 2016-10-05  21453100
# ...

# %% [markdown]
# #### 20 日的移動平均

# %%
df.Close.plot()
df.Close.rolling(20).mean()
# Out:
# Date
# 2016-10-03           NaN
# 2016-10-04           NaN
# 2016-10-05           NaN
# 2016-10-06           NaN
# 2016-10-07           NaN
#                  ...
# 2017-12-04    172.694001
# 2017-12-05    172.463501
# 2017-12-06    172.173501
# 2017-12-07    171.827501
# 2017-12-08    171.502000
# Name: Close, Length: 300, dtype: float64

# %%
df.Close.rolling(20).mean().plot()

# %% [markdown]
# #### 20 日和 60 日的移動平均

# %%
df.Close.plot(legend=True)
df.Close.rolling(20).mean().plot(label="$MA_{20}$",legend=True)
df.Close.rolling(60).mean().plot(label="$MA_{60}$",legend=True)

# %% [markdown]
# #### 準備做預測
#
# 我們用個非常天真的模型...
#
# ![天真股票模型](images/naive.png)
#
# 網路上說這是線性的 (可能嗎)!

# %%
close = df.Close.values
len(close)
# Out:
# 300

# %%
x = close[:-1]
len(x)
# Out:
# 299

# %%
y = close[1:]
len(y)
# Out:
# 299

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %% [markdown]
# 哦, 真的有點像線性的, 我們之後用線性迴歸試試看。

# %% [markdown]
# ## 9 手工打造一個 DataFrame*
#
# 有時我們用手工打造一個簡單的 DataFrame, 可以更理解整個結構。其實很容易, 一個 DataFrame 基本上就包含兩個主要部份:
#
# * 資料本身: 通常一個二維陣列 (矩陣)
# * 行、列的名稱
#
# 我們來個簡單的小例子。

# %%
mydata = np.random.randn(4,3)

# %%
mydata
# Out:
# array([[-0.39865713,  0.25444684,  2.16565736],
#        [ 0.25644533,  2.56967909,  0.18366785],
#        [ 1.91259421, -0.29231042,  0.49283515],
#        [-0.15655822,  0.24247562,  0.81117866]])

# %% [markdown]
# 把行列的名字放進去, 就成一個 DataFrame。我們列的部份先讓 Python 自己產生。

# %%
df2 = pd.DataFrame(mydata, columns=list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0  0.518666  1.749743  0.764451
# 1  0.082908 -0.429956 -1.360554
# 2  1.771713  0.969037 -0.422924
# 3 -0.381373  1.121223 -0.551245

# %% [markdown]
# #### 兩個表格上下貼起來
#
# 我們再來生一個 DataFrame, 再「貼」起來。

# %%
df3 = pd.DataFrame(np.random.randn(3,3), columns=list("ABC"))

# %%
df3
# Out:
#           A         B         C
# 0  1.675135 -0.640597  0.688107
# 1  1.550468  0.078462 -0.064319
# 2 -0.182654 -0.229135 -0.166753

# %%
df4 = pd.concat([df2, df3], axis = 0)

# %%
df4
# Out:
#           A         B         C
# 0 -0.398657  0.254447  2.165657
# 1  0.256445  2.569679  0.183668
# 2  1.912594 -0.292310  0.492835
# 3 -0.156558  0.242476  0.811179
# 0 -0.007452 -2.260748 -0.605434
# 1 -1.511722 -1.259594  1.654429
# 2  1.574761 -0.304873  1.317939

# %% [markdown]
# 前面我們弄得亂七八糟的 index 重設一下。

# %%
df4.index = range(7)

# %%
df4
# Out:
#           A         B         C
# 0 -0.398657  0.254447  2.165657
# 1  0.256445  2.569679  0.183668
# 2  1.912594 -0.292310  0.492835
# 3 -0.156558  0.242476  0.811179
# 4 -0.007452 -2.260748 -0.605434
# 5 -1.511722 -1.259594  1.654429
# 6  1.574761 -0.304873  1.317939

# %% [markdown]
# #### 横向的貼

# %%
df5 = pd.concat([df2, df3], axis = 1)

# %% [markdown]
# 等等, 這大小好像不太對也可以嗎? 答案是可以的!

# %%
df5
# Out:
#           A         B         C         A         B         C
# 0 -0.398657  0.254447  2.165657 -0.007452 -2.260748 -0.605434
# 1  0.256445  2.569679  0.183668 -1.511722 -1.259594  1.654429
# 2  1.912594 -0.292310  0.492835  1.574761 -0.304873  1.317939
# 3 -0.156558  0.242476  0.811179       NaN       NaN       NaN

# %% [markdown]
# #### 大一點的例子
#
# 我們來做前面「假的」學測資料。首先要有「假的」同學名單, 如果有興趣產生很多名字, 可以用這個服務。
#
# [中文姓名產生器](http://www.richyli.com/name/index.asp)

# %%
df_names = pd.read_csv("/content/drive/MyDrive/IMLP375/Unit02/data/names.csv", names = ["姓名"])

# %%
df_names.head()
# Out:
#     姓名
# 0  羅雅慧
# 1  王紹尹
# 2  黃季坤
# 3  許正書
# 4  張鈞蓮

# %%
df_grades = pd.DataFrame(np.random.randint(6,16,(100,5)),
                        columns=['國文','英文','數學','社會','自然'])

# %%
df_grades.to_csv('/content/drive/MyDrive/IMLP375/Unit02/data/grade2.csv')

# %%
df_grades
# Out:
#     國文  英文  數學  社會  自然
# 0   10  13  14   8   6
# 1   15   7   9  14  14
# 2   14  14  13   8  13
# 3   11  12  10  12   8
# 4   15  14  11   9  10
# ..  ..  ..  ..  ..  ..
# 95   7  11  15  10  15
# 96   7  11  15   8  10
# 97   7  12  12  13   7
# 98  11  10   8   8  14
# 99   7  11   6   6  15
#
# [100 rows x 5 columns]

# %%
df_score = pd.concat([df_names, df_grades], axis = 1)

# %%
df_score
# Out:
#      姓名  國文  英文  數學  社會  自然
# 0   羅雅慧  10  13  14   8   6
# 1   王紹尹  15   7   9  14  14
# 2   黃季坤  14  14  13   8  13
# 3   許正書  11  12  10  12   8
# 4   張鈞蓮  15  14  11   9  10
# ..  ...  ..  ..  ..  ..  ..
# 95  陳君生   7  11  15  10  15
# 96  曾桂甫   7  11  15   8  10
# 97  林欣怡   7  12  12  13   7
# 98  林佳霖  11  10   8   8  14
# 99  胡筱芸   7  11   6   6  15
#
# [100 rows x 6 columns]
